# %%
import os
import pandas as pd
import openpyxl
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/kwakdong-u/Downloads/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_서울_202303.csv',
                encoding = 'UTF-8')

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df['상권업종대분류명'].unique()
# Out:
# array(['음식', '숙박', '교육', '과학·기술', '소매', '시설관리·임대', '수리·개인', '부동산',
#        '예술·스포츠', '보건의료'], dtype=object)

# %%
df = df[df['상권업종대분류명'] == '음식']
# Out:
#                       상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA0101202210A0037544    영자's곱창  NaN        I2       음식      I201
# 4       MA010120220805430767       토끼정  NaN        I2       음식      I201
# 5       MA010120220805430778  스쿨푸드딜리버리  NaN        I2       음식      I210
# 6       MA010120220805430797       가배차  NaN        I2       음식      I201
# 7       MA010120220805430812  비에이치씨항동점  NaN        I2       음식      I210
# ...                      ...       ...  ...       ...      ...       ...
# 474234  MA0101202302A0090704    프롬별파스타  NaN        I2       음식      I204
# 474243  MA0101202302A0061740       연만두  NaN        I2       음식      I210
# 474246  MA0101202302A0071039    비기닝브레드  NaN        I2       음식      I210
# 474250  MA0101202302A0064407      용두홍어  NaN        I2       음식      I201
# 474257  MA0101202302A0036033       루젤라  NaN        I2       음식      I204
#
#        상권업종중분류명 상권업종소분류코드  상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# ...

# %%
df['상권업종중분류명'].unique()
# Out:
# array(['한식', '일반 숙박', '기타 교육', '사진 촬영', '기타 간이', '의약·화장품 소매', '광고',
#        '운송장비 대여', '비알코올 ', '섬유·의복·신발 소매', '욕탕·신체관리', '종합 소매', '이용·미용',
#        '자동차 수리·세차', '식료품 소매', '중식', '부동산 서비스', '법무관련 ', '컴퓨터 수리',
#        '시계·귀금속 소매', '본사·경영 컨설팅', '전문 디자인', '가전·통신 소매', '중고 상품 소매', '주점',
#        '스포츠 서비스', '회계·세무', '애완동물·용품 소매', '세탁', '기타 전문 과학', '기술 서비스', '의원',
#        '동남아시아', '기타 가정용품 수리', '유원지·오락', '서양식', '교육 지원', '청소·방제',
#        '기타 사업 서비스', '가정용품 대여', '고용 알선', '장식품 소매', '일반 교육', '구내식당·뷔페',
#        '음료 소매', '여행사·보조', '기타 개인', '기타 상품 소매', '기타 생활용품 소매', '식물 소매',
#        '기타 숙박', '일식', '오락용품 소매', '인쇄·제품제작', '가구 소매', '가전제품 수리', '기타 보건',
#        '도서관·사적지', '담배 소매', '수의', '시장 조사', '시설관리', '병원', '모터사이클 소매',
#        '철물·건설자재 소매', '안경·정밀기기 소매', '자동차 부품 소매', '모터사이클 수리', '연료 소매',
#        '산업용품 대여', '사무 지원', '통신장비 수리', '조경·유지', '장례식장 '], dtype=object)

# %%
df[df['상호명'] == '이디야']
# Out:
#                       상가업소번호  상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 7702    MA010120220805927608  이디야   NaN        I2       음식      I212    비알코올
# 33961   MA010120220806995459  이디야   NaN        I2       음식      I212    비알코올
# 39039   MA010120220807134016  이디야   NaN        I2       음식      I212    비알코올
# 43512   MA010120220807438617  이디야   NaN        I2       음식      I212    비알코올
# 43965   MA010120220807441663  이디야   NaN        I2       음식      I212    비알코올
# ...                      ...  ...   ...       ...      ...       ...      ...
# 448679  MA010120220805247515  이디야   NaN        I2       음식      I212    비알코올
# 450930  MA010120220805372602  이디야   NaN        I2       음식      I212    비알코올
# 452213  MA010120220805328967  이디야   NaN        I2       음식      I212    비알코올
# 455368  MA010120220805216388  이디야   NaN        I2       음식      I212    비알코올
# 471659  MA0101202302A0073269  이디야  미아역점        I2       음식      I212    비알코올
#
# ...

# %%
df_run = pd.read_excel('/Users/kwakdong-u/Downloads/07_24_05_P_휴게음식점.xlsx', engine = "openpyxl",
                      usecols = [5, 8,17,18,19,20,21,26,27])

# %%
df_run.columns
# Out:
# Index(['인허가일자', '영업상태명', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호', '사업장명',
#        '좌표정보(X)', '좌표정보(Y)'],
#       dtype='object')

# %%
df_run
# Out:
#           인허가일자  영업상태명  소재지우편번호                        소재지전체주소  \
# 0    2023-05-17  영업/정상  131-820     서울특별시 중랑구 면목동 179-24 늘찬병원
# 1    2023-05-12  영업/정상  131-848    서울특별시 중랑구 묵동 170-1 묵동자이아파트
# 2    2023-04-27  영업/정상  110-062      서울특별시 종로구 신문로2가 1-117 1층
# 3    2023-04-17  영업/정상  150-036        서울특별시 영등포구 영등포동6가 49-1
# 4    2023-03-24  영업/정상  136-818          서울특별시 성북구 석관동 246-10
# ..          ...    ...      ...                            ...
# 598  2001-11-09  영업/정상  135-887       서울특별시 강남구 신사동 512-10 1층
# 599  2001-09-14  영업/정상  110-825          서울특별시 종로구 숭인동 200-13
# 600  2001-07-02  영업/정상  100-813     서울특별시 중구 서소문동 53-1번지 지상1층
# 601  2001-06-22  영업/정상  136-052       서울특별시 성북구 동선동2가 305-0번지
# 602  1992-02-26  영업/정상  137-927  서울특별시 서초구 서초동 1451-1 원일빌딩 1층
#
#                                         도로명전체주소  도로명우편번호         사업장명  \
# 0              서울특별시 중랑구 동일로 643, 늘찬병원 1층 (면목동)   2135.0  이디야 면목늘찬병원점
# 1    서울특별시 중랑구 동일로 932, 1층 2-120호 (묵동, 묵동자이아파트)   2033.0    이디야 중랑묵동점
# ...

# %%
df_stop = pd.read_excel('/Users/kwakdong-u/Downloads/07_24_05_P_휴게음식점 (1).xlsx', engine = "openpyxl",
                      usecols = [5, 8,17,18,19,20,21,26,27])

# %%
df_stop
# Out:
#           인허가일자 영업상태명  소재지우편번호                                     소재지전체주소  \
# 0    2021-07-07    폐업  131-826                        서울특별시 중랑구 면목동 646-3
# 1    2021-01-26    폐업  157-210  서울특별시 강서구 마곡동 776-2 마곡센트럴대방디엠시티오피스텔 제비108호
# 2    2020-05-28    폐업  136-800                 서울특별시 성북구 길음동 25-7 삼주빌딩 1층
# 3    2020-01-14    폐업  120-190     서울특별시 서대문구 북아현동 1015 e편한세상신촌 4단지 1층110호
# 4    2019-12-27    폐업  121-880                   서울특별시 마포구 창전동 5-92 창무예술원
# ..          ...   ...      ...                                         ...
# 201  2001-05-15    폐업  152-824                     서울특별시 구로구 고척동 52-200번지
# 202  2000-11-08    폐업  156-801                     서울특별시 동작구 노량진동 148-8번지
# 203  2000-06-29    폐업  156-800                     서울특별시 동작구 노량진동 100-3번지
# 204  2000-01-26    폐업  150-034                 서울특별시 영등포구 영등포동4가 441-21번지
# 205  1999-06-29    폐업  120-808                        서울특별시 서대문구 대현동 40-7
#
#                                                도로명전체주소  도로명우편번호  \
# ...

# %%
df_eydia = pd.concat([df_run, df_stop], axis=0)

# %% [markdown]
# 중부원점 TM(EPSG : 2097)좌표계

# %%
df_eydia
# Out:
#           인허가일자  영업상태명  소재지우편번호                      소재지전체주소  \
# 0    2023-05-17  영업/정상  131-820   서울특별시 중랑구 면목동 179-24 늘찬병원
# 1    2023-05-12  영업/정상  131-848  서울특별시 중랑구 묵동 170-1 묵동자이아파트
# 2    2023-04-27  영업/정상  110-062    서울특별시 종로구 신문로2가 1-117 1층
# 3    2023-04-17  영업/정상  150-036      서울특별시 영등포구 영등포동6가 49-1
# 4    2023-03-24  영업/정상  136-818        서울특별시 성북구 석관동 246-10
# ..          ...    ...      ...                          ...
# 201  2001-05-15     폐업  152-824      서울특별시 구로구 고척동 52-200번지
# 202  2000-11-08     폐업  156-801      서울특별시 동작구 노량진동 148-8번지
# 203  2000-06-29     폐업  156-800      서울특별시 동작구 노량진동 100-3번지
# 204  2000-01-26     폐업  150-034  서울특별시 영등포구 영등포동4가 441-21번지
# 205  1999-06-29     폐업  120-808         서울특별시 서대문구 대현동 40-7
#
#                                         도로명전체주소  도로명우편번호         사업장명  \
# 0              서울특별시 중랑구 동일로 643, 늘찬병원 1층 (면목동)   2135.0  이디야 면목늘찬병원점
# 1    서울특별시 중랑구 동일로 932, 1층 2-120호 (묵동, 묵동자이아파트)   2033.0    이디야 중랑묵동점
# ...

# %%
df_stop = pd.read_excel('/Users/kwakdong-u/Downloads/07_24_05_P_휴게음식점 (1).xlsx', engine = "openpyxl",
                      usecols = [5, 8,17,18,19,20,21,26,27])

# %%
folders = ['이디야', '투썸', '파스쿠찌', '폴바셋', '할리스']
df_all = pd.DataFrame()
root_path = '/Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사'

# %%
for folder in folders:
    for file in os.listdir(os.path.join(root_path, folder)):
        df = pd.read_excel(os.path.join(root_path, folder, file), engine = "openpyxl",
                      usecols = [5, 8,11,17,18,19,20,21,26,27])
        print(os.path.join(root_path, folder, file))
        df_all = pd.concat([df_all, df], axis = 0, ignore_index=False)
# Out:
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/이디야/07_24_05_P_휴게음식점.xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/이디야/07_24_05_P_휴게음식점 (1).xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/투썸/07_24_05_P_휴게음식점 (2).xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/투썸/07_24_05_P_휴게음식점 (3).xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/파스쿠찌/07_24_05_P_휴게음식점.xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/파스쿠찌/07_24_05_P_휴게음식점 (1).xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/폴바셋/07_24_05_P_휴게음식점.xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/폴바셋/07_24_05_P_휴게음식점 (1).xlsx
# ...

# %%
df_all
# Out:
#           인허가일자  영업상태명 폐업일자  소재지우편번호                               소재지전체주소  \
# 0    2023-05-17  영업/정상  NaN  131-820            서울특별시 중랑구 면목동 179-24 늘찬병원
# 1    2023-05-12  영업/정상  NaN  131-848           서울특별시 중랑구 묵동 170-1 묵동자이아파트
# 2    2023-04-27  영업/정상  NaN  110-062             서울특별시 종로구 신문로2가 1-117 1층
# 3    2023-04-17  영업/정상  NaN  150-036               서울특별시 영등포구 영등포동6가 49-1
# 4    2023-03-24  영업/정상  NaN  136-818                 서울특별시 성북구 석관동 246-10
# ..          ...    ...  ...      ...                                   ...
# 109  2005-04-04  영업/정상  NaN  138-934                   서울특별시 송파구 신천동 11-7
# 110  2004-07-09  영업/정상  NaN  120-180    서울특별시 서대문구 창천동 31-12 ,13 (1,2,3층)
# 111  2001-10-18  영업/정상  NaN  135-090        서울특별시 강남구 삼성동 159-0번지 무역센타 1층
# 112  1999-12-16  영업/정상  NaN  135-892            서울특별시 강남구 신사동 580-0번지 105
# 113  1998-04-28  영업/정상  NaN  143-721  서울특별시 광진구 구의동 546-4번지 테크노마트 9층동 014호
#
#                                         도로명전체주소  도로명우편번호           사업장명  \
# ...

# %%
folderss = ['더벤티', '메가커피', '빽다방']
df_a = pd.DataFrame()
root_path = '/Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사'

# %%
for folder in folderss:
    for file in os.listdir(os.path.join(root_path, folder)):
        df = pd.read_excel(os.path.join(root_path, folder, file), engine = "openpyxl",
                      usecols = [5, 8, 11,17,18,19,20,21,26,27])
        print(os.path.join(root_path, folder, file))
        
        df_a = pd.concat([df_a, df], axis = 0, ignore_index=False)
# Out:
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/더벤티/07_24_05_P_휴게음식점 (2).xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/더벤티/07_24_05_P_휴게음식점 (3).xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/메가커피/07_24_05_P_휴게음식점.xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/메가커피/07_24_05_P_휴게음식점 (1).xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/빽다방/07_24_05_P_휴게음식점 (2).xlsx
# /Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/빽다방/07_24_05_P_휴게음식점 (3).xlsx

# %%
df_a
# Out:
#           인허가일자  영업상태명 폐업일자  소재지우편번호  \
# 0    2023-06-01  영업/정상  NaN  133-809
# 1    2023-05-18  영업/정상  NaN  138-240
# 2    2023-05-18  영업/정상  NaN  158-818
# 3    2023-05-15  영업/정상  NaN  152-848
# 4    2023-05-15  영업/정상  NaN  122-842
# ..          ...    ...  ...      ...
# 211  2010-02-12  영업/정상  NaN  136-075
# 212  2008-08-18  영업/정상  NaN  135-840
# 213  2008-04-22  영업/정상  NaN  136-865
# 214  2007-07-18  영업/정상  NaN  100-450
# 215  2005-10-28  영업/정상  NaN  139-860
#
#                                             소재지전체주소  \
# 0                        서울특별시 성동구 금호동4가 1382 설당빌딩
# 1                          서울특별시 송파구 신천동 20-6 파크리오
# 2                              서울특별시 양천구 목동 767-10
# 3                 서울특별시 구로구 구로동 197-28 이앤씨벤처드림타워6차
# 4                          서울특별시 은평구 대조동 185-36 1층
# ..                                              ...
# 211                          서울특별시 성북구 안암동5가 100-5
# 212  서울특별시 강남구 대치동 893-0번지 롯데캐슬(아)생활편의시설 지하1층 B14호
# ...

# %%
#파일 저장코드
df_a.to_csv('/Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/fight_cheap.csv', index=False, encoding='euc-kr')

# %%
#파일 저장코드
df_all.to_csv('/Users/kwakdong-u/Library/CloudStorage/OneDrive-UOS/스타벅스 유동인구 팀플/경쟁사/fight_expensive.csv', index=False, encoding='euc-kr')
